# %% [markdown]
# <a href="https://colab.research.google.com/github/Marc-Serenio/CPEN-21A-CpE-1-1/blob/main/Laboratory_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Welcome to Python Programming**

# %%
print("welcome to Python Programming")
# Out:
# welcome to Python Programming

# %%
name, age = "Marc", 19

# %%
address = "Brgy. Lumbreras GMA, Cavite"

# %%
print ("Name: {}\nAddress: {}\nAge : {}".format (name, address, age))
# Out:
# Name: Marc
# Address: Brgy. Lumbreras GMA, Cavite
# Age : 19
